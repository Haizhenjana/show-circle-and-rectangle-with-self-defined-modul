# %%
from ModulGeometry import *
# imports all files of self defined modul

# %%
RedRectangle=rectangle.Rectangle(10,10,"r")
# create a object of class Rectangle
RedRectangle.drawRectangle()

# %%
BlueCircle = circle.Circle(20, "blue")
BlueCircle.drawCircle()
